# %% [markdown]
# # Problem Set 4
#
# #### Question 4: Participation in 401K

# %%
# Loading the data 
library(wooldridge)
data("k401k")
k401k.data <- force(k401k)
k401k.data
# Out:
#      prate mrate totpart totelg age totemp sole ltotemp
# 1     26.1 0.21  1653    6322    8  8709   0    9.072112
# 2    100.0 1.42   262     262    6   315   1    5.752573
# 3     97.6 0.91   166     170   10   275   1    5.616771
# 4    100.0 0.42   257     257    7   500   0    6.214608
# 5     82.5 0.53   591     716   28   933   1    6.838405
# 6    100.0 1.82    92      92    7   143   1    4.962845
# 7    100.0 0.53   399     399   31   628   1    6.442540
# 8     92.5 0.34   210     227   13   823   0    6.712956
# 9    100.0 0.22   234     234   21   279   1    5.631212
# 10    96.8 0.60   120     124   10   141   1    4.948760
# 11    83.0 0.50   156     188    5   252   0    5.529429
# 12   100.0 1.11   187     187   20   237   1    5.468060
# 13    65.5 0.43   350     534    5   681   1    6.523562
# 14    84.9 0.51  1519    1790   10  2557   0    7.846590
# 15   100.0 0.19   150     150    7   187   1    5.231109
# ...

# %%
# 4a 
print(mean(k401k.data$prate))
print(mean(k401k.data$mrate))
# Out:
# [1] 87.36291
# [1] 0.7315124

# %%
ols.model <- lm(formula = prate ~ mrate, data = force(k401k.data))
summary(ols.model)
# Out:
# Call:
# lm(formula = prate ~ mrate, data = force(k401k.data))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -82.303  -8.184   5.178  12.712  16.807
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  83.0755     0.5633  147.48   <2e-16 ***
# mrate         5.8611     0.5270   11.12   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 16.09 on 1532 degrees of freedom
# Multiple R-squared:  0.0747,	Adjusted R-squared:  0.0741
# F-statistic: 123.7 on 1 and 1532 DF,  p-value: < 2.2e-16

# %%
summary(ols.model)
# Out:
# [1] "k401k"

# %%
83.0755 + (5.8611 * 3.5)
# Out:
# [1] 103.5894
